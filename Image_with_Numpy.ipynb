# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharana23/Computer-Vision/blob/master/Image_with_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
pic = Image.open('/content/00-puppy.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.array(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
#RED
plt.imshow(pic_red[:, :, 0])

# %%
#RED CHANNEL
plt.imshow(pic_red[:, :, 0], cmap='gray')

# %%
#GREEN CHANNEL
plt.imshow(pic_arr[:, :, 1], cmap='gray')

# %%
#BLUE CHANNEL
plt.imshow(pic_red[:, :, 2], cmap='gray')

# %%
#GREEN CHANNEL = 0
pic_red[:, :, 1] = 0
plt.imshow(pic_red)

# %%
#BLUE CHANNEL = 0
pic_red[:, :, 2] = 0
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (1300, 1950, 3)

# %%
pic_red[:, :, 0].shape
# Out:
# (1300, 1950)
